# %% [markdown]
# <a href="https://colab.research.google.com/github/25gs10608-prog/2026AI/blob/main/%EA%B9%80%EC%A3%BC%ED%98%81%20-%20%EC%9D%B8%EA%B8%B0%EC%B4%88(%EA%B9%83%ED%97%99).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Github Test')
# Out:
# Github Test

# %%
# !git clone https://github.com/25gs10608-prog/2026data.git
# Out:
# Cloning into '2026data'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), 5.35 KiB | 5.35 MiB/s, done.

# %%
cd 2026data
# Out:
# /content/2026data

# %%
ls
# Out:
# heart_test.csv  README.md
